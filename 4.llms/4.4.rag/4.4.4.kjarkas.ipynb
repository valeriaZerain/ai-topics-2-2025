# %%
import requests
from bs4 import BeautifulSoup

kjarkas_id = 8988
saviaandina_id = 37055
calamarka_id = 23997
angelesazules_id = 16643
mana_id = 9300



def extract_lyrics_links(artist_url: str) -> list[str]:
    response = requests.get(url=artist_url)
    print(f"Response from artist page: {response.status_code}")
    soup = BeautifulSoup(response.text, "html.parser")
    links_ul = soup.find("ul", class_="listado-letras")
    links = [a["href"] for a in links_ul.find_all("a")]
    return links

def extract_song_lyric(song_url: str) -> str:
    response = requests.get(url=song_url)
    response.encoding = "utf-8"
    print(f"Response from lyrics page: {response.status_code}")
    soup = BeautifulSoup(response.text, "html.parser")
    song_title = soup.find("h1").get_text()
    print(f"Title: {song_title}")
    header = soup.find("h2", string="LETRA")
    if header is None:
        header = soup.find("h2", string="LETRA EN ESPAÑOL")
        
    if header is None:
        return ""

    paragraphs = []

    for p in header.find_all_next("p"):
        if p.find_parent("div") is None:
            continue
        if p.find_parent("div").get("id") == "letra":
            paragraphs.append(p.get_text(separator="\n"))

    lyrics = "\n".join(p for p in paragraphs)
    return f"Título: {song_title} \n\n {lyrics}"

def extract_artist_lyrics(artist: str, artist_id: int):
    lyrics_url = f"https://www.musica.com/letras.asp?letras={artist_id}&orden=alf"
    links = extract_lyrics_links(lyrics_url)
    print(f"found {len(links)} songs")
    artist_header = f"{artist}\n===\n"
    lyrics = []
    for link in links:
        print(f"extracting song from: {link}")
        lyrics.append(extract_song_lyric(link))
    lyrics_str = "\n\n===\n\n".join(lyrics)
    artist_str = artist_header + lyrics_str
    with open(f"{artist_id}_{artist}.txt", "w", encoding="utf-8") as file:
        file.write(artist_str)
    return artist_str

# %%
extract_artist_lyrics("Kjarkas", kjarkas_id)
extract_artist_lyrics("Savia Andina", saviaandina_id)
extract_artist_lyrics("Calamarka", calamarka_id)
extract_artist_lyrics("Angeles Azules", angelesazules_id)
extract_artist_lyrics("Mana", mana_id)
# Out:
# Response from artist page: 200
# found 166 songs
# extracting song from: https://www.musica.com/letras.asp?letra=1645995
# Response from lyrics page: 200
# Title: A las orillas del rio
# extracting song from: https://www.musica.com/letras.asp?letra=1567692
# Response from lyrics page: 200
# Title: A los 500 años
# extracting song from: https://www.musica.com/letras.asp?letra=2066364
# Response from lyrics page: 200
# Title: A nadie
# extracting song from: https://www.musica.com/letras.asp?letra=989973
# Response from lyrics page: 200
# Title: A que volviste
# extracting song from: https://www.musica.com/letras.asp?letra=1645999
# Response from lyrics page: 200
# Title: A tu ventana
# extracting song from: https://www.musica.com/letras.asp?letra=2108958
# Response from lyrics page: 200
# Title: Acto Final
# extracting song from: https://www.musica.com/letras.asp?letra=6580
# Response from lyrics page: 200
# Title: Al Final
# extracting song from: https://www.musica.com/letras.asp?letra=989976
# Response from lyrics page: 200
# Title: Al partir
# extracting song from: https://www.musica.com/letras.asp?letra=1660921
# Response from lyrics page: 200
# Title: Amarte siempre
# extracting song from: https://www.musica.com/letras.asp?letra=2035673
# Response from lyrics page: 200
# Title: Angel y demonio
# extracting song from: https://www.musica.com/letras.asp?letra=987514
# Response from lyrics page: 200
# Title: Arbol De Mi Destino
# extracting song from: https://www.musica.com/letras.asp?letra=1756358
# Response from lyrics page: 200
# Title: Atravez de un ollo In
# extracting song from: https://www.musica.com/letras.asp?letra=11166
# Response from lyrics page: 200
# Title: Ave De Cristal
# extracting song from: https://www.musica.com/letras.asp?letra=987539
# Response from lyrics page: 200
# Title: Ay corazón
# extracting song from: https://www.musica.com/letras.asp?letra=2073497
# Response from lyrics page: 200
# Title: Ay de mí
# extracting song from: https://www.musica.com/letras.asp?letra=1382540
# Response from lyrics page: 200
# Title: Bolivia
# extracting song from: https://www.musica.com/letras.asp?letra=1660937
# Response from lyrics page: 200
# Title: Camargo
# extracting song from: https://www.musica.com/letras.asp?letra=1110048
# Response from lyrics page: 200
# Title: Canción para mi hija
# extracting song from: https://www.musica.com/letras.asp?letra=1660941
# Response from lyrics page: 200
# Title: Canto a la madre
# extracting song from: https://www.musica.com/letras.asp?letra=1506482
# Response from lyrics page: 200
# Title: Canto a la mujer de mi pueblo
# extracting song from: https://www.musica.com/letras.asp?letra=2074856
# Response from lyrics page: 200
# Title: Cholita anzaldeñita
# extracting song from: https://www.musica.com/letras.asp?letra=2027284
# Response from lyrics page: 200
# Title: Chulla
# extracting song from: https://www.musica.com/letras.asp?letra=1263274
# Response from lyrics page: 200
# Title: Chuquiago Marka
# extracting song from: https://www.musica.com/letras.asp?letra=1757171
# Response from lyrics page: 200
# Title: Cicatrices
# extracting song from: https://www.musica.com/letras.asp?letra=1667112
# Response from lyrics page: 200
# Title: Ciudad del alto
# extracting song from: https://www.musica.com/letras.asp?letra=1766792
# Response from lyrics page: 200
# Title: Como duele el corazón
# extracting song from: https://www.musica.com/letras.asp?letra=1183515
# Response from lyrics page: 200
# Title: Como has hecho
# extracting song from: https://www.musica.com/letras.asp?letra=922593
# Response from lyrics page: 200
# Title: Cómo olvidarte
# extracting song from: https://www.musica.com/letras.asp?letra=1667114
# Response from lyrics page: 200
# Title: Como siempre soñe
# extracting song from: https://www.musica.com/letras.asp?letra=1668605
# Response from lyrics page: 200
# Title: con la puerta cerrada
# extracting song from: https://www.musica.com/letras.asp?letra=2075335
# Response from lyrics page: 200
# Title: Condor celoso
# extracting song from: https://www.musica.com/letras.asp?letra=2027296
# Response from lyrics page: 200
# Title: Condor Mallcu
# extracting song from: https://www.musica.com/letras.asp?letra=1682210
# Response from lyrics page: 200
# Title: Contra el viento
# extracting song from: https://www.musica.com/letras.asp?letra=1684395
# Response from lyrics page: 200
# Title: Corazon a corazon
# extracting song from: https://www.musica.com/letras.asp?letra=1691788
# Response from lyrics page: 200
# Title: Creo en ti
# extracting song from: https://www.musica.com/letras.asp?letra=2073517
# Response from lyrics page: 200
# Title: Cuatro estamos en tu puerta
# extracting song from: https://www.musica.com/letras.asp?letra=990010
# Response from lyrics page: 200
# Title: Dejaras
# extracting song from: https://www.musica.com/letras.asp?letra=1799902
# Response from lyrics page: 200
# Title: Deje mi querencia
# extracting song from: https://www.musica.com/letras.asp?letra=1787039
# Response from lyrics page: 200
# Title: Desde mi ventana
# extracting song from: https://www.musica.com/letras.asp?letra=1629044
# Response from lyrics page: 200
# Title: Dificil de olvidar
# extracting song from: https://www.musica.com/letras.asp?letra=892339
# Response from lyrics page: 200
# Title: Duele
# extracting song from: https://www.musica.com/letras.asp?letra=1263279
# Response from lyrics page: 200
# Title: Dulce compañera
# extracting song from: https://www.musica.com/letras.asp?letra=1691797
# Response from lyrics page: 200
# Title: El adios
# extracting song from: https://www.musica.com/letras.asp?letra=1742171
# Response from lyrics page: 200
# Title: El amor y la libertad
# extracting song from: https://www.musica.com/letras.asp?letra=887018
# Response from lyrics page: 200
# Title: El Árbol de mi Destino
# extracting song from: https://www.musica.com/letras.asp?letra=1744768
# Response from lyrics page: 200
# Title: El dia que yo me vaya
# extracting song from: https://www.musica.com/letras.asp?letra=964307
# Response from lyrics page: 200
# Title: El hombre equivocado
# extracting song from: https://www.musica.com/letras.asp?letra=1691813
# Response from lyrics page: 200
# Title: El lider de los humildes
# extracting song from: https://www.musica.com/letras.asp?letra=1696851
# Response from lyrics page: 200
# Title: El picaflor
# extracting song from: https://www.musica.com/letras.asp?letra=987511
# Response from lyrics page: 200
# Title: El Ritmo Negro
# extracting song from: https://www.musica.com/letras.asp?letra=1244991
# Response from lyrics page: 200
# Title: El Ultimo amanecer
# extracting song from: https://www.musica.com/letras.asp?letra=1639579
# Response from lyrics page: 200
# Title: Ella es
# extracting song from: https://www.musica.com/letras.asp?letra=817937
# Response from lyrics page: 200
# Title: En la soledad
# extracting song from: https://www.musica.com/letras.asp?letra=2078392
# Response from lyrics page: 200
# Title: En un abril
# extracting song from: https://www.musica.com/letras.asp?letra=1243354
# Response from lyrics page: 200
# Title: Entre el infierno y la grloria
# extracting song from: https://www.musica.com/letras.asp?letra=2078397
# Response from lyrics page: 200
# Title: Flor aiquileña
# extracting song from: https://www.musica.com/letras.asp?letra=1624189
# Response from lyrics page: 200
# Title: Flor de potosi
# extracting song from: https://www.musica.com/letras.asp?letra=1904122
# Response from lyrics page: 200
# Title: Florcita azul
# extracting song from: https://www.musica.com/letras.asp?letra=1377899
# Response from lyrics page: 200
# Title: Fria
# extracting song from: https://www.musica.com/letras.asp?letra=1647862
# Response from lyrics page: 200
# Title: Hagamos el amor
# extracting song from: https://www.musica.com/letras.asp?letra=1263270
# Response from lyrics page: 200
# Title: Hermanos
# extracting song from: https://www.musica.com/letras.asp?letra=1037608
# Response from lyrics page: 200
# Title: Hombre Equivocado
# extracting song from: https://www.musica.com/letras.asp?letra=2346502
# Response from lyrics page: 200
# Title: Huellas en mi alma
# extracting song from: https://www.musica.com/letras.asp?letra=892335
# Response from lyrics page: 200
# Title: Imillitay
# extracting song from: https://www.musica.com/letras.asp?letra=1696854
# Response from lyrics page: 200
# Title: Ingratitud
# extracting song from: https://www.musica.com/letras.asp?letra=964304
# Response from lyrics page: 200
# Title: Jilguero Flores
# extracting song from: https://www.musica.com/letras.asp?letra=1904124
# Response from lyrics page: 200
# Title: Jiyaway Sambita
# extracting song from: https://www.musica.com/letras.asp?letra=1646059
# Response from lyrics page: 200
# Title: Kamanchaca
# extracting song from: https://www.musica.com/letras.asp?letra=2073493
# Response from lyrics page: 200
# Title: Kjochisitu pampa verde
# extracting song from: https://www.musica.com/letras.asp?letra=2111547
# Response from lyrics page: 200
# Title: Kutimuy en español
# extracting song from: https://www.musica.com/letras.asp?letra=922587
# Response from lyrics page: 200
# Title: La mujer que llegó
# extracting song from: https://www.musica.com/letras.asp?letra=1869462
# Response from lyrics page: 200
# Title: La oración del Pajarito
# extracting song from: https://www.musica.com/letras.asp?letra=987535
# Response from lyrics page: 200
# Title: La Pícara
# extracting song from: https://www.musica.com/letras.asp?letra=1242598
# Response from lyrics page: 200
# Title: La triunfal
# extracting song from: https://www.musica.com/letras.asp?letra=922586
# Response from lyrics page: 200
# Title: La ventana
# extracting song from: https://www.musica.com/letras.asp?letra=2073490
# Response from lyrics page: 200
# Title: Lágrimas en tu mejilla
# extracting song from: https://www.musica.com/letras.asp?letra=1576118
# Response from lyrics page: 200
# Title: Lección de Vida
# extracting song from: https://www.musica.com/letras.asp?letra=2135962
# Response from lyrics page: 200
# Title: Llévame
# extracting song from: https://www.musica.com/letras.asp?letra=63391
# Response from lyrics page: 200
# Title: Llorando De Fué
# extracting song from: https://www.musica.com/letras.asp?letra=991614
# Response from lyrics page: 200
# Title: Llorando se fue
# extracting song from: https://www.musica.com/letras.asp?letra=1649872
# Response from lyrics page: 200
# Title: Loco por ti
# extracting song from: https://www.musica.com/letras.asp?letra=1242769
# Response from lyrics page: 200
# Title: Los morenos
# extracting song from: https://www.musica.com/letras.asp?letra=1766833
# Response from lyrics page: 200
# Title: Lunareja
# extracting song from: https://www.musica.com/letras.asp?letra=1242599
# Response from lyrics page: 200
# Title: Mas bella tu
# extracting song from: https://www.musica.com/letras.asp?letra=1766801
# Response from lyrics page: 200
# Title: Mentiroso corazón
# extracting song from: https://www.musica.com/letras.asp?letra=987533
# Response from lyrics page: 200
# Title: Mi Gran Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1245146
# Response from lyrics page: 200
# Title: Mi pecado
# extracting song from: https://www.musica.com/letras.asp?letra=1242649
# Response from lyrics page: 200
# Title: Mi Samba, mi negra
# extracting song from: https://www.musica.com/letras.asp?letra=1629040
# Response from lyrics page: 200
# Title: Mi santa cruz
# extracting song from: https://www.musica.com/letras.asp?letra=2279079
# Response from lyrics page: 200
# Title: Mi Santa Cruz de la Sierra
# extracting song from: https://www.musica.com/letras.asp?letra=1245000
# Response from lyrics page: 200
# Title: Mi Sueño Mejor
# extracting song from: https://www.musica.com/letras.asp?letra=1646062
# Response from lyrics page: 200
# Title: Mi vida sin tu amor
# extracting song from: https://www.musica.com/letras.asp?letra=1650654
# Response from lyrics page: 200
# Title: Morenada chacaltaya
# extracting song from: https://www.musica.com/letras.asp?letra=2073491
# Response from lyrics page: 200
# Title: Muchacha de alas blancas
# extracting song from: https://www.musica.com/letras.asp?letra=1122170
# Response from lyrics page: 200
# Title: Munasq'echay
# extracting song from: https://www.musica.com/letras.asp?letra=2073360
# Response from lyrics page: 200
# Title: Necesito un amor
# extracting song from: https://www.musica.com/letras.asp?letra=990011
# Response from lyrics page: 200
# Title: Negrita
# extracting song from: https://www.musica.com/letras.asp?letra=1773430
# Response from lyrics page: 200
# Title: Niña
# extracting song from: https://www.musica.com/letras.asp?letra=2006017
# Response from lyrics page: 200
# Title: Niño de América
# extracting song from: https://www.musica.com/letras.asp?letra=1801055
# Response from lyrics page: 200
# Title: No Podre Saber
# extracting song from: https://www.musica.com/letras.asp?letra=1321697
# Response from lyrics page: 200
# Title: No te puedo olvidar
# extracting song from: https://www.musica.com/letras.asp?letra=894510
# Response from lyrics page: 200
# Title: No temas enamorarte
# extracting song from: https://www.musica.com/letras.asp?letra=893992
# Response from lyrics page: 200
# Title: No vuelvo amar
# extracting song from: https://www.musica.com/letras.asp?letra=1766750
# Response from lyrics page: 200
# Title: Nunca mi amor
# extracting song from: https://www.musica.com/letras.asp?letra=987510
# Response from lyrics page: 200
# Title: Oruro tierra de amor
# extracting song from: https://www.musica.com/letras.asp?letra=2069753
# Response from lyrics page: 200
# Title: Pachacamak
# extracting song from: https://www.musica.com/letras.asp?letra=1766737
# Response from lyrics page: 200
# Title: Paloma Blanca
# extracting song from: https://www.musica.com/letras.asp?letra=2074857
# Response from lyrics page: 200
# Title: Pampa palomita
# extracting song from: https://www.musica.com/letras.asp?letra=1608787
# Response from lyrics page: 200
# Title: pando
# extracting song from: https://www.musica.com/letras.asp?letra=987525
# Response from lyrics page: 200
# Title: Pensando en Ti
# extracting song from: https://www.musica.com/letras.asp?letra=2078362
# Response from lyrics page: 200
# Title: Pequeña Aymarita
# extracting song from: https://www.musica.com/letras.asp?letra=892963
# Response from lyrics page: 200
# Title: Pequeño amor
# extracting song from: https://www.musica.com/letras.asp?letra=987530
# Response from lyrics page: 200
# Title: Perdóname
# extracting song from: https://www.musica.com/letras.asp?letra=987544
# Response from lyrics page: 200
# Title: Por Tus caprichos
# extracting song from: https://www.musica.com/letras.asp?letra=83001
# Response from lyrics page: 200
# Title: Por Un Mundo Nuevo
# extracting song from: https://www.musica.com/letras.asp?letra=1977549
# Response from lyrics page: 200
# Title: Pueblos perdidos
# extracting song from: https://www.musica.com/letras.asp?letra=987522
# Response from lyrics page: 200
# Title: Puedo Vivir Sin Tu Amor
# extracting song from: https://www.musica.com/letras.asp?letra=2253306
# Response from lyrics page: 200
# Title: Quejas del Alma
# extracting song from: https://www.musica.com/letras.asp?letra=1218705
# Response from lyrics page: 200
# Title: Quiero saber
# extracting song from: https://www.musica.com/letras.asp?letra=1414033
# Response from lyrics page: 200
# Title: Recuerdos
# extracting song from: https://www.musica.com/letras.asp?letra=1245225
# Response from lyrics page: 200
# Title: Sabe Dios cuanto te quiero
# extracting song from: https://www.musica.com/letras.asp?letra=1037601
# Response from lyrics page: 200
# Title: Santusay
# extracting song from: https://www.musica.com/letras.asp?letra=1173870
# Response from lyrics page: 200
# Title: Saya caporal
# extracting song from: https://www.musica.com/letras.asp?letra=1541923
# Response from lyrics page: 200
# Title: Saya cochabanba
# extracting song from: https://www.musica.com/letras.asp?letra=1242730
# Response from lyrics page: 200
# Title: Saya de San Andrés
# extracting song from: https://www.musica.com/letras.asp?letra=990013
# Response from lyrics page: 200
# Title: Saya Morena
# extracting song from: https://www.musica.com/letras.asp?letra=1647854
# Response from lyrics page: 200
# Title: Saya negra
# extracting song from: https://www.musica.com/letras.asp?letra=985908
# Response from lyrics page: 200
# Title: Saya sensual
# extracting song from: https://www.musica.com/letras.asp?letra=1121734
# Response from lyrics page: 200
# Title: Secreto Amor
# extracting song from: https://www.musica.com/letras.asp?letra=964303
# Response from lyrics page: 200
# Title: Señora su hija
# extracting song from: https://www.musica.com/letras.asp?letra=93889
# Response from lyrics page: 200
# Title: Siempre He De Adorarte
# extracting song from: https://www.musica.com/letras.asp?letra=94306
# Response from lyrics page: 200
# Title: Sin Ella
# extracting song from: https://www.musica.com/letras.asp?letra=1977449
# Response from lyrics page: 200
# Title: Sol de los andes
# extracting song from: https://www.musica.com/letras.asp?letra=990012
# Response from lyrics page: 200
# Title: Soledad
# extracting song from: https://www.musica.com/letras.asp?letra=1415346
# Response from lyrics page: 200
# Title: Solo
# extracting song from: https://www.musica.com/letras.asp?letra=1766743
# Response from lyrics page: 200
# Title: Solo yo he ganado
# extracting song from: https://www.musica.com/letras.asp?letra=934452
# Response from lyrics page: 200
# Title: Son tantas noches
# extracting song from: https://www.musica.com/letras.asp?letra=1587868
# Response from lyrics page: 200
# Title: Sucre
# extracting song from: https://www.musica.com/letras.asp?letra=1977544
# Response from lyrics page: 200
# Title: Sueño de los andes
# extracting song from: https://www.musica.com/letras.asp?letra=1263285
# Response from lyrics page: 200
# Title: Surimana
# extracting song from: https://www.musica.com/letras.asp?letra=1667998
# Response from lyrics page: 200
# Title: Tarde
# extracting song from: https://www.musica.com/letras.asp?letra=1626523
# Response from lyrics page: 200
# Title: Tarija
# extracting song from: https://www.musica.com/letras.asp?letra=2027283
# Response from lyrics page: 200
# Title: Tata inti
# extracting song from: https://www.musica.com/letras.asp?letra=1004156
# Response from lyrics page: 200
# Title: Te amo a ti
# extracting song from: https://www.musica.com/letras.asp?letra=1594515
# Response from lyrics page: 200
# Title: Te llevas todo Amor
# extracting song from: https://www.musica.com/letras.asp?letra=2254094
# Response from lyrics page: 200
# Title: Te vine a ver
# extracting song from: https://www.musica.com/letras.asp?letra=112204
# Response from lyrics page: 200
# Title: Tiempo Al Tiempo
# extracting song from: https://www.musica.com/letras.asp?letra=2027286
# Response from lyrics page: 200
# Title: Tierra Chaqueña
# extracting song from: https://www.musica.com/letras.asp?letra=1242697
# Response from lyrics page: 200
# Title: Todo me habla de ti
# extracting song from: https://www.musica.com/letras.asp?letra=2099868
# Response from lyrics page: 200
# Title: Tomas Orujo
# extracting song from: https://www.musica.com/letras.asp?letra=2099867
# Response from lyrics page: 200
# Title: Tomas Orujo en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1080348
# Response from lyrics page: 200
# Title: Tuna Papita
# extracting song from: https://www.musica.com/letras.asp?letra=1242662
# Response from lyrics page: 200
# Title: Tupiza
# extracting song from: https://www.musica.com/letras.asp?letra=990006
# Response from lyrics page: 200
# Title: Tus 15 años y yo
# extracting song from: https://www.musica.com/letras.asp?letra=1611594
# Response from lyrics page: 200
# Title: Ukhamampi Munataxa
# extracting song from: https://www.musica.com/letras.asp?letra=1263282
# Response from lyrics page: 200
# Title: Último amanecer
# extracting song from: https://www.musica.com/letras.asp?letra=2073531
# Response from lyrics page: 200
# Title: Verde limoncito
# extracting song from: https://www.musica.com/letras.asp?letra=1624884
# Response from lyrics page: 200
# Title: Viva cochabamba
# extracting song from: https://www.musica.com/letras.asp?letra=1773232
# Response from lyrics page: 200
# Title: Viven en mi
# extracting song from: https://www.musica.com/letras.asp?letra=985906
# Response from lyrics page: 200
# Title: Vivir junto a ti
# extracting song from: https://www.musica.com/letras.asp?letra=2121848
# Response from lyrics page: 200
# Title: Vivo Por Ti
# extracting song from: https://www.musica.com/letras.asp?letra=2139792
# Response from lyrics page: 200
# Title: Vuelve
# extracting song from: https://www.musica.com/letras.asp?letra=1037603
# Response from lyrics page: 200
# Title: Wayayay
# extracting song from: https://www.musica.com/letras.asp?letra=2261116
# Response from lyrics page: 200
# Title: Yo no he nacido para sufrir
# extracting song from: https://www.musica.com/letras.asp?letra=2121850
# Response from lyrics page: 200
# Title: Yo Vivo Por Ti
# extracting song from: https://www.musica.com/letras.asp?letra=1938972
# Response from lyrics page: 200
# Title: Yuyariway Urpi
# Response from artist page: 200
# found 13 songs
# extracting song from: https://www.musica.com/letras.asp?letra=1813463
# Response from lyrics page: 200
# Title: A los bosques
# extracting song from: https://www.musica.com/letras.asp?letra=1813477
# Response from lyrics page: 200
# Title: Adios oruro del alma
# extracting song from: https://www.musica.com/letras.asp?letra=1813472
# Response from lyrics page: 200
# Title: Amorosa Palomita
# extracting song from: https://www.musica.com/letras.asp?letra=1813482
# Response from lyrics page: 200
# Title: Cacharpaya del Indio
# extracting song from: https://www.musica.com/letras.asp?letra=1813489
# Response from lyrics page: 200
# Title: El Cisne
# extracting song from: https://www.musica.com/letras.asp?letra=1813495
# Response from lyrics page: 200
# Title: El Guajojo
# extracting song from: https://www.musica.com/letras.asp?letra=1870477
# Response from lyrics page: 200
# Title: El minero
# extracting song from: https://www.musica.com/letras.asp?letra=1988205
# Response from lyrics page: 200
# Title: Eterno Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1813499
# Response from lyrics page: 200
# Title: La Mentirosita
# extracting song from: https://www.musica.com/letras.asp?letra=1813503
# Response from lyrics page: 200
# Title: Mi Socio
# extracting song from: https://www.musica.com/letras.asp?letra=1813509
# Response from lyrics page: 200
# Title: Por que estás triste
# extracting song from: https://www.musica.com/letras.asp?letra=1813504
# Response from lyrics page: 200
# Title: Quirquinchito Charanguito
# extracting song from: https://www.musica.com/letras.asp?letra=1813467
# Response from lyrics page: 200
# Title: Verbenita
# Response from artist page: 200
# found 47 songs
# extracting song from: https://www.musica.com/letras.asp?letra=2110809
# Response from lyrics page: 200
# Title: A miami
# extracting song from: https://www.musica.com/letras.asp?letra=1313233
# Response from lyrics page: 200
# Title: Agua dulce y amor
# extracting song from: https://www.musica.com/letras.asp?letra=1179148
# Response from lyrics page: 200
# Title: Aguas Claras
# extracting song from: https://www.musica.com/letras.asp?letra=1440541
# Response from lyrics page: 200
# Title: Ama sua Ama llulla Ama quella
# extracting song from: https://www.musica.com/letras.asp?letra=1179145
# Response from lyrics page: 200
# Title: Amazonas
# extracting song from: https://www.musica.com/letras.asp?letra=1880480
# Response from lyrics page: 200
# Title: America
# extracting song from: https://www.musica.com/letras.asp?letra=1280325
# Response from lyrics page: 200
# Title: Baila caliente
# extracting song from: https://www.musica.com/letras.asp?letra=1956187
# Response from lyrics page: 200
# Title: Bailando Tobadas
# extracting song from: https://www.musica.com/letras.asp?letra=1880464
# Response from lyrics page: 200
# Title: Bolivianita
# extracting song from: https://www.musica.com/letras.asp?letra=1295751
# Response from lyrics page: 200
# Title: Busco a Huamanga
# extracting song from: https://www.musica.com/letras.asp?letra=1892409
# Response from lyrics page: 200
# Title: Celia
# extracting song from: https://www.musica.com/letras.asp?letra=1680645
# Response from lyrics page: 200
# Title: Cochabambinita
# extracting song from: https://www.musica.com/letras.asp?letra=2234752
# Response from lyrics page: 200
# Title: Compañera
# extracting song from: https://www.musica.com/letras.asp?letra=1217602
# Response from lyrics page: 200
# Title: Cuando florezca el chuño
# extracting song from: https://www.musica.com/letras.asp?letra=1806110
# Response from lyrics page: 200
# Title: De los andes a los alpees
# extracting song from: https://www.musica.com/letras.asp?letra=1179188
# Response from lyrics page: 200
# Title: El Jaguar
# extracting song from: https://www.musica.com/letras.asp?letra=1833118
# Response from lyrics page: 200
# Title: Es asi
# extracting song from: https://www.musica.com/letras.asp?letra=1880469
# Response from lyrics page: 200
# Title: Es para ti
# extracting song from: https://www.musica.com/letras.asp?letra=2389726
# Response from lyrics page: 200
# Title: Esmeralda
# extracting song from: https://www.musica.com/letras.asp?letra=2098854
# Response from lyrics page: 200
# Title: Eternal
# extracting song from: https://www.musica.com/letras.asp?letra=1179152
# Response from lyrics page: 200
# Title: Fiebre y Saya
# extracting song from: https://www.musica.com/letras.asp?letra=1805941
# Response from lyrics page: 200
# Title: Florcita del Ande
# extracting song from: https://www.musica.com/letras.asp?letra=1429577
# Response from lyrics page: 200
# Title: Guardian del Amazonas
# extracting song from: https://www.musica.com/letras.asp?letra=2066598
# Response from lyrics page: 200
# Title: He venido
# extracting song from: https://www.musica.com/letras.asp?letra=2121276
# Response from lyrics page: 200
# Title: Jaguar
# extracting song from: https://www.musica.com/letras.asp?letra=1275024
# Response from lyrics page: 200
# Title: La historia de Pancarita
# extracting song from: https://www.musica.com/letras.asp?letra=1407883
# Response from lyrics page: 200
# Title: La Rosa
# extracting song from: https://www.musica.com/letras.asp?letra=2540478
# Response from lyrics page: 200
# Title: Llamerada
# extracting song from: https://www.musica.com/letras.asp?letra=1777473
# Response from lyrics page: 200
# Title: Malacum wawapa
# extracting song from: https://www.musica.com/letras.asp?letra=1179156
# Response from lyrics page: 200
# Title: Mamita
# extracting song from: https://www.musica.com/letras.asp?letra=1228053
# Response from lyrics page: 200
# Title: Mía (max castro)
# extracting song from: https://www.musica.com/letras.asp?letra=2192320
# Response from lyrics page: 200
# Title: Niña de mis ojos
# extracting song from: https://www.musica.com/letras.asp?letra=1805942
# Response from lyrics page: 200
# Title: Pastorcita
# extracting song from: https://www.musica.com/letras.asp?letra=1438038
# Response from lyrics page: 200
# Title: Pequeño Juanito
# extracting song from: https://www.musica.com/letras.asp?letra=1805787
# Response from lyrics page: 200
# Title: Perder mi juventud
# extracting song from: https://www.musica.com/letras.asp?letra=2389727
# Response from lyrics page: 200
# Title: Ponchos Rojos
# extracting song from: https://www.musica.com/letras.asp?letra=2292513
# Response from lyrics page: 200
# Title: Por algo de Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1191254
# Response from lyrics page: 200
# Title: Primavera
# extracting song from: https://www.musica.com/letras.asp?letra=1455139
# Response from lyrics page: 200
# Title: Pujllayman tusuy
# extracting song from: https://www.musica.com/letras.asp?letra=1860662
# Response from lyrics page: 200
# Title: Raices
# extracting song from: https://www.musica.com/letras.asp?letra=2389731
# Response from lyrics page: 200
# Title: Rosa
# extracting song from: https://www.musica.com/letras.asp?letra=2389729
# Response from lyrics page: 200
# Title: Siempre te amaré
# extracting song from: https://www.musica.com/letras.asp?letra=1806101
# Response from lyrics page: 200
# Title: Sol
# extracting song from: https://www.musica.com/letras.asp?letra=1806122
# Response from lyrics page: 200
# Title: Solo por ti
# extracting song from: https://www.musica.com/letras.asp?letra=2267545
# Response from lyrics page: 200
# Title: Tobas Rosa
# extracting song from: https://www.musica.com/letras.asp?letra=1805781
# Response from lyrics page: 200
# Title: Tupak Katari
# extracting song from: https://www.musica.com/letras.asp?letra=1425418
# Response from lyrics page: 200
# Title: Yo te ame yo te amare
# Response from artist page: 200
# found 144 songs
# extracting song from: https://www.musica.com/letras.asp?letra=841490
# Response from lyrics page: 200
# Title: 17 años
# extracting song from: https://www.musica.com/letras.asp?letra=1236732
# Response from lyrics page: 200
# Title: 17 años en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=898891
# Response from lyrics page: 200
# Title: 20 Rosas
# extracting song from: https://www.musica.com/letras.asp?letra=2508953
# Response from lyrics page: 200
# Title: 20 Rosas
# extracting song from: https://www.musica.com/letras.asp?letra=2486888
# Response from lyrics page: 200
# Title: Acaríñame
# extracting song from: https://www.musica.com/letras.asp?letra=2271535
# Response from lyrics page: 200
# Title: Acercate a Mí
# extracting song from: https://www.musica.com/letras.asp?letra=879629
# Response from lyrics page: 200
# Title: Amigos nada más
# extracting song from: https://www.musica.com/letras.asp?letra=2476267
# Response from lyrics page: 200
# Title: Amor a Primera Vista
# extracting song from: https://www.musica.com/letras.asp?letra=2466842
# Response from lyrics page: 200
# Title: Amor A Primera Vista
# extracting song from: https://www.musica.com/letras.asp?letra=970977
# Response from lyrics page: 200
# Title: Amor de mis amores
# extracting song from: https://www.musica.com/letras.asp?letra=1648171
# Response from lyrics page: 200
# Title: Amor de novela
# extracting song from: https://www.musica.com/letras.asp?letra=1385101
# Response from lyrics page: 200
# Title: Amor de una madre
# extracting song from: https://www.musica.com/letras.asp?letra=954107
# Response from lyrics page: 200
# Title: Amor secreto
# extracting song from: https://www.musica.com/letras.asp?letra=2341389
# Response from lyrics page: 200
# Title: Amor sin suerte
# extracting song from: https://www.musica.com/letras.asp?letra=2430863
# Response from lyrics page: 200
# Title: Antes que al mío
# extracting song from: https://www.musica.com/letras.asp?letra=2243853
# Response from lyrics page: 200
# Title: Así soy
# extracting song from: https://www.musica.com/letras.asp?letra=954126
# Response from lyrics page: 200
# Title: Aunque no estes conmigo.
# extracting song from: https://www.musica.com/letras.asp?letra=1151656
# Response from lyrics page: 200
# Title: Ay Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1382806
# Response from lyrics page: 200
# Title: Besar tu Piel
# extracting song from: https://www.musica.com/letras.asp?letra=1255362
# Response from lyrics page: 200
# Title: Busquenla
# extracting song from: https://www.musica.com/letras.asp?letra=1244121
# Response from lyrics page: 200
# Title: Cheque cancelado
# extracting song from: https://www.musica.com/letras.asp?letra=1871790
# Response from lyrics page: 200
# Title: Chica atrevida
# extracting song from: https://www.musica.com/letras.asp?letra=1050255
# Response from lyrics page: 200
# Title: Cicatrices
# extracting song from: https://www.musica.com/letras.asp?letra=816869
# Response from lyrics page: 200
# Title: Como Te Voy A Olvidar
# extracting song from: https://www.musica.com/letras.asp?letra=2521960
# Response from lyrics page: 200
# Title: Cómo Te Voy A Olvidar
# extracting song from: https://www.musica.com/letras.asp?letra=1049638
# Response from lyrics page: 200
# Title: Creí en ti
# extracting song from: https://www.musica.com/letras.asp?letra=1050256
# Response from lyrics page: 200
# Title: Cuando llegastes tú
# extracting song from: https://www.musica.com/letras.asp?letra=2547862
# Response from lyrics page: 200
# Title: Cumbia A La Gente
# extracting song from: https://www.musica.com/letras.asp?letra=2278306
# Response from lyrics page: 200
# Title: Cumbia Angelical
# extracting song from: https://www.musica.com/letras.asp?letra=2279320
# Response from lyrics page: 200
# Title: Cumbia Candelosa
# extracting song from: https://www.musica.com/letras.asp?letra=2278308
# Response from lyrics page: 200
# Title: Cumbia De La Paz
# extracting song from: https://www.musica.com/letras.asp?letra=2279319
# Response from lyrics page: 200
# Title: Cumbia Del Infinito (Versión Original 1993)
# extracting song from: https://www.musica.com/letras.asp?letra=2271536
# Response from lyrics page: 200
# Title: Cumbia Güajira
# extracting song from: https://www.musica.com/letras.asp?letra=2280746
# Response from lyrics page: 200
# Title: Cumbia Más Tropical
# extracting song from: https://www.musica.com/letras.asp?letra=2151788
# Response from lyrics page: 200
# Title: Cumbia Pa' Gozar
# extracting song from: https://www.musica.com/letras.asp?letra=2278309
# Response from lyrics page: 200
# Title: Cumbia Querida
# extracting song from: https://www.musica.com/letras.asp?letra=2279321
# Response from lyrics page: 200
# Title: Cumbia Sabrosona
# extracting song from: https://www.musica.com/letras.asp?letra=1554730
# Response from lyrics page: 200
# Title: Deja llamarte amor
# extracting song from: https://www.musica.com/letras.asp?letra=954138
# Response from lyrics page: 200
# Title: Desde que te vi
# extracting song from: https://www.musica.com/letras.asp?letra=2386808
# Response from lyrics page: 200
# Title: Detrás de Mi Ventana
# extracting song from: https://www.musica.com/letras.asp?letra=1495520
# Response from lyrics page: 200
# Title: Diecisiete años
# extracting song from: https://www.musica.com/letras.asp?letra=1050257
# Response from lyrics page: 200
# Title: Diferencias
# extracting song from: https://www.musica.com/letras.asp?letra=1244105
# Response from lyrics page: 200
# Title: Dime, dime
# extracting song from: https://www.musica.com/letras.asp?letra=2341452
# Response from lyrics page: 200
# Title: Divorciate
# extracting song from: https://www.musica.com/letras.asp?letra=2596605
# Response from lyrics page: 200
# Title: El Amor de Mi Vida
# extracting song from: https://www.musica.com/letras.asp?letra=2425006
# Response from lyrics page: 200
# Title: El amor después del amor
# extracting song from: https://www.musica.com/letras.asp?letra=2508537
# Response from lyrics page: 200
# Title: El Ángel Que Nos Une
# extracting song from: https://www.musica.com/letras.asp?letra=2558760
# Response from lyrics page: 200
# Title: El Día Del Exnovio
# extracting song from: https://www.musica.com/letras.asp?letra=816819
# Response from lyrics page: 200
# Title: El listón de tu pelo
# extracting song from: https://www.musica.com/letras.asp?letra=2278133
# Response from lyrics page: 200
# Title: El Negrito Cumbiambero
# extracting song from: https://www.musica.com/letras.asp?letra=2278131
# Response from lyrics page: 200
# Title: El Nuevo Sonido De La Cumbia
# extracting song from: https://www.musica.com/letras.asp?letra=1550717
# Response from lyrics page: 200
# Title: El Pecado
# extracting song from: https://www.musica.com/letras.asp?letra=954085
# Response from lyrics page: 200
# Title: Ella se olvido de mi
# extracting song from: https://www.musica.com/letras.asp?letra=816818
# Response from lyrics page: 200
# Title: Entrega de Amor
# extracting song from: https://www.musica.com/letras.asp?letra=2225141
# Response from lyrics page: 200
# Title: Existe Un Corazón
# extracting song from: https://www.musica.com/letras.asp?letra=1050258
# Response from lyrics page: 200
# Title: Falsa Mujer
# extracting song from: https://www.musica.com/letras.asp?letra=2609527
# Response from lyrics page: 200
# Title: Felicítalo
# extracting song from: https://www.musica.com/letras.asp?letra=1244117
# Response from lyrics page: 200
# Title: Házmelo saber
# extracting song from: https://www.musica.com/letras.asp?letra=2265666
# Response from lyrics page: 200
# Title: Hermoso Bebé
# extracting song from: https://www.musica.com/letras.asp?letra=1111866
# Response from lyrics page: 200
# Title: Juventud
# extracting song from: https://www.musica.com/letras.asp?letra=2623757
# Response from lyrics page: 200
# Title: La Cadenita
# extracting song from: https://www.musica.com/letras.asp?letra=2139656
# Response from lyrics page: 200
# Title: La Cumbia del Acordeon
# extracting song from: https://www.musica.com/letras.asp?letra=2139654
# Response from lyrics page: 200
# Title: La Cumbia del Infinito
# extracting song from: https://www.musica.com/letras.asp?letra=2511875
# Response from lyrics page: 200
# Title: La Cumbia del Infinito
# extracting song from: https://www.musica.com/letras.asp?letra=1038854
# Response from lyrics page: 200
# Title: La hice llorar
# extracting song from: https://www.musica.com/letras.asp?letra=1008167
# Response from lyrics page: 200
# Title: La hice sufrir
# extracting song from: https://www.musica.com/letras.asp?letra=2278130
# Response from lyrics page: 200
# Title: La Reina De Colombia
# extracting song from: https://www.musica.com/letras.asp?letra=2220117
# Response from lyrics page: 200
# Title: La Vecina
# extracting song from: https://www.musica.com/letras.asp?letra=2257139
# Response from lyrics page: 200
# Title: Las Estrellas Hablan De Ti
# extracting song from: https://www.musica.com/letras.asp?letra=2151786
# Response from lyrics page: 200
# Title: Las Maravillas de la Vida
# extracting song from: https://www.musica.com/letras.asp?letra=2518910
# Response from lyrics page: 200
# Title: Las Maravillas De La Vida
# extracting song from: https://www.musica.com/letras.asp?letra=951446
# Response from lyrics page: 200
# Title: Llorar y llorar
# extracting song from: https://www.musica.com/letras.asp?letra=953946
# Response from lyrics page: 200
# Title: Los angeles azules
# extracting song from: https://www.musica.com/letras.asp?letra=2280752
# Response from lyrics page: 200
# Title: María Isabel
# extracting song from: https://www.musica.com/letras.asp?letra=1896657
# Response from lyrics page: 200
# Title: Me Dijiste Que No
# extracting song from: https://www.musica.com/letras.asp?letra=954151
# Response from lyrics page: 200
# Title: Me haces falta tú
# extracting song from: https://www.musica.com/letras.asp?letra=2279322
# Response from lyrics page: 200
# Title: Me Quiero Inspirar
# extracting song from: https://www.musica.com/letras.asp?letra=831128
# Response from lyrics page: 200
# Title: Mentías
# extracting song from: https://www.musica.com/letras.asp?letra=970978
# Response from lyrics page: 200
# Title: Mi cantar
# extracting song from: https://www.musica.com/letras.asp?letra=911449
# Response from lyrics page: 200
# Title: Mi confección
# extracting song from: https://www.musica.com/letras.asp?letra=852268
# Response from lyrics page: 200
# Title: Mi Niña Mujer
# extracting song from: https://www.musica.com/letras.asp?letra=924159
# Response from lyrics page: 200
# Title: Mi pequeña
# extracting song from: https://www.musica.com/letras.asp?letra=2139657
# Response from lyrics page: 200
# Title: Mi unico amor
# extracting song from: https://www.musica.com/letras.asp?letra=1244157
# Response from lyrics page: 200
# Title: Mis sentimientos
# extracting song from: https://www.musica.com/letras.asp?letra=2342221
# Response from lyrics page: 200
# Title: Mujer o estrella
# extracting song from: https://www.musica.com/letras.asp?letra=1244414
# Response from lyrics page: 200
# Title: Mujercita encantadora
# extracting song from: https://www.musica.com/letras.asp?letra=1247038
# Response from lyrics page: 200
# Title: Muriendo a pausas
# extracting song from: https://www.musica.com/letras.asp?letra=2380979
# Response from lyrics page: 200
# Title: Ni Contigo, Ni Sin Ti
# extracting song from: https://www.musica.com/letras.asp?letra=1220032
# Response from lyrics page: 200
# Title: No me vuelvo a enamorar
# extracting song from: https://www.musica.com/letras.asp?letra=1785554
# Response from lyrics page: 200
# Title: No vale la pena
# extracting song from: https://www.musica.com/letras.asp?letra=2379502
# Response from lyrics page: 200
# Title: Nunca Es Suficiente
# extracting song from: https://www.musica.com/letras.asp?letra=2561645
# Response from lyrics page: 200
# Title: Otra Noche
# extracting song from: https://www.musica.com/letras.asp?letra=2280750
# Response from lyrics page: 200
# Title: Oye Mi Cumbia
# extracting song from: https://www.musica.com/letras.asp?letra=2303979
# Response from lyrics page: 200
# Title: Paso la vida pensando
# extracting song from: https://www.musica.com/letras.asp?letra=1396245
# Response from lyrics page: 200
# Title: Perdon
# extracting song from: https://www.musica.com/letras.asp?letra=1011260
# Response from lyrics page: 200
# Title: Perdóname mi amor
# extracting song from: https://www.musica.com/letras.asp?letra=1245766
# Response from lyrics page: 200
# Title: Perdóname, olvídalo
# extracting song from: https://www.musica.com/letras.asp?letra=2610142
# Response from lyrics page: 200
# Title: Perdonarte ¿Para Qué?
# extracting song from: https://www.musica.com/letras.asp?letra=2260082
# Response from lyrics page: 200
# Title: Picaito
# extracting song from: https://www.musica.com/letras.asp?letra=1352760
# Response from lyrics page: 200
# Title: Pichoncito
# extracting song from: https://www.musica.com/letras.asp?letra=2266491
# Response from lyrics page: 200
# Title: Piénsalo Bien
# extracting song from: https://www.musica.com/letras.asp?letra=1239640
# Response from lyrics page: 200
# Title: Platiquemos juntos
# extracting song from: https://www.musica.com/letras.asp?letra=1412491
# Response from lyrics page: 200
# Title: Pobres Niños
# extracting song from: https://www.musica.com/letras.asp?letra=823741
# Response from lyrics page: 200
# Title: Por el Amor a mi madre
# extracting song from: https://www.musica.com/letras.asp?letra=1273490
# Response from lyrics page: 200
# Title: Por tu amor
# extracting song from: https://www.musica.com/letras.asp?letra=1060555
# Response from lyrics page: 200
# Title: Primer amor
# extracting song from: https://www.musica.com/letras.asp?letra=1245750
# Response from lyrics page: 200
# Title: Que bien te ves
# extracting song from: https://www.musica.com/letras.asp?letra=1696163
# Response from lyrics page: 200
# Title: Que corazon tuviste tu
# extracting song from: https://www.musica.com/letras.asp?letra=1660753
# Response from lyrics page: 200
# Title: Que inocencia
# extracting song from: https://www.musica.com/letras.asp?letra=1286854
# Response from lyrics page: 200
# Title: Que levante la mano
# extracting song from: https://www.musica.com/letras.asp?letra=1247027
# Response from lyrics page: 200
# Title: Que tonto fui
# extracting song from: https://www.musica.com/letras.asp?letra=1050259
# Response from lyrics page: 200
# Title: Querida
# extracting song from: https://www.musica.com/letras.asp?letra=1175094
# Response from lyrics page: 200
# Title: Quiero ser
# extracting song from: https://www.musica.com/letras.asp?letra=1544539
# Response from lyrics page: 200
# Title: Quiero ser tu amigo nada mas
# extracting song from: https://www.musica.com/letras.asp?letra=2585350
# Response from lyrics page: 200
# Title: Quiero Ser Yo Ese Hombre
# extracting song from: https://www.musica.com/letras.asp?letra=1463877
# Response from lyrics page: 200
# Title: Quinceañera
# extracting song from: https://www.musica.com/letras.asp?letra=1791344
# Response from lyrics page: 200
# Title: Recuerda Cuando Fuimos Novios
# extracting song from: https://www.musica.com/letras.asp?letra=1413961
# Response from lyrics page: 200
# Title: Rompecabezas De Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1179420
# Response from lyrics page: 200
# Title: Siempre en mi mente
# extracting song from: https://www.musica.com/letras.asp?letra=2470244
# Response from lyrics page: 200
# Title: Siempre junto a ti
# extracting song from: https://www.musica.com/letras.asp?letra=954091
# Response from lyrics page: 200
# Title: Sin ti no se vivir
# extracting song from: https://www.musica.com/letras.asp?letra=2514331
# Response from lyrics page: 200
# Title: Soltero
# extracting song from: https://www.musica.com/letras.asp?letra=1010736
# Response from lyrics page: 200
# Title: Suelta el listón de tu pelo
# extracting song from: https://www.musica.com/letras.asp?letra=2275203
# Response from lyrics page: 200
# Title: Sueño Con Estar Contigo
# extracting song from: https://www.musica.com/letras.asp?letra=1049637
# Response from lyrics page: 200
# Title: Te extraño tanto
# extracting song from: https://www.musica.com/letras.asp?letra=2342222
# Response from lyrics page: 200
# Title: Te lo creo
# extracting song from: https://www.musica.com/letras.asp?letra=1036999
# Response from lyrics page: 200
# Title: Te necesito
# extracting song from: https://www.musica.com/letras.asp?letra=2266396
# Response from lyrics page: 200
# Title: Te Olvidaste
# extracting song from: https://www.musica.com/letras.asp?letra=970979
# Response from lyrics page: 200
# Title: Te quiero para mi
# extracting song from: https://www.musica.com/letras.asp?letra=1247024
# Response from lyrics page: 200
# Title: Tengo algo para tí
# extracting song from: https://www.musica.com/letras.asp?letra=1050254
# Response from lyrics page: 200
# Title: Tiene Espinas El Rosal
# extracting song from: https://www.musica.com/letras.asp?letra=2265564
# Response from lyrics page: 200
# Title: Toma Que Toma
# extracting song from: https://www.musica.com/letras.asp?letra=2041892
# Response from lyrics page: 200
# Title: Traición de los Dos
# extracting song from: https://www.musica.com/letras.asp?letra=1123251
# Response from lyrics page: 200
# Title: Tu Carcel
# extracting song from: https://www.musica.com/letras.asp?letra=1193687
# Response from lyrics page: 200
# Title: Tu juguete
# extracting song from: https://www.musica.com/letras.asp?letra=2590338
# Response from lyrics page: 200
# Title: Tú y Tú
# extracting song from: https://www.musica.com/letras.asp?letra=840812
# Response from lyrics page: 200
# Title: Un sueño
# extracting song from: https://www.musica.com/letras.asp?letra=2280744
# Response from lyrics page: 200
# Title: Un Tecito
# extracting song from: https://www.musica.com/letras.asp?letra=2271537
# Response from lyrics page: 200
# Title: Virgen De Guadalupe
# extracting song from: https://www.musica.com/letras.asp?letra=1097428
# Response from lyrics page: 200
# Title: Y la hice llorar
# extracting song from: https://www.musica.com/letras.asp?letra=2504678
# Response from lyrics page: 200
# Title: Y La Hice Llorar
# extracting song from: https://www.musica.com/letras.asp?letra=1527551
# Response from lyrics page: 200
# Title: Y que
# extracting song from: https://www.musica.com/letras.asp?letra=2620906
# Response from lyrics page: 200
# Title: Yo Me Lo Busqué
# extracting song from: https://www.musica.com/letras.asp?letra=1608173
# Response from lyrics page: 200
# Title: Yo Te Amo
# Response from artist page: 200
# found 199 songs
# extracting song from: https://www.musica.com/letras.asp?letra=2216649
# Response from lyrics page: 200
# Title: Adicto A Tu Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1424405
# Response from lyrics page: 200
# Title: Ahi esta la luna
# extracting song from: https://www.musica.com/letras.asp?letra=8155
# Response from lyrics page: 200
# Title: Ámame Hasta Que Me Muera
# extracting song from: https://www.musica.com/letras.asp?letra=1148030
# Response from lyrics page: 200
# Title: Ámame Hasta Que Me Muera en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1956467
# Response from lyrics page: 200
# Title: Amor Clandestino
# extracting song from: https://www.musica.com/letras.asp?letra=904690
# Response from lyrics page: 200
# Title: Ana
# extracting song from: https://www.musica.com/letras.asp?letra=1871184
# Response from lyrics page: 200
# Title: Andres Molina Eriquez
# extracting song from: https://www.musica.com/letras.asp?letra=8923
# Response from lyrics page: 200
# Title: Ángel De Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1025116
# Response from lyrics page: 200
# Title: Ángel De Amor en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=828726
# Response from lyrics page: 200
# Title: Antifaz
# extracting song from: https://www.musica.com/letras.asp?letra=1148036
# Response from lyrics page: 200
# Title: Antifaz en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1291197
# Response from lyrics page: 200
# Title: Arde el cielo
# extracting song from: https://www.musica.com/letras.asp?letra=894071
# Response from lyrics page: 200
# Title: Arráncame el corazón
# extracting song from: https://www.musica.com/letras.asp?letra=1148039
# Response from lyrics page: 200
# Title: Arráncame el corazón en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1148042
# Response from lyrics page: 200
# Title: Ay doctor en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=11329
# Response from lyrics page: 200
# Title: Ay, Doctor
# extracting song from: https://www.musica.com/letras.asp?letra=801432
# Response from lyrics page: 200
# Title: Baila morena
# ...
# Response from lyrics page: 200
# Title: Lentes de sol
# extracting song from: https://www.musica.com/letras.asp?letra=1941051
# Response from lyrics page: 200
# Title: Lluvia al Corazón
# extracting song from: https://www.musica.com/letras.asp?letra=1946823
# Response from lyrics page: 200
# Title: Luz y Drama
# extracting song from: https://www.musica.com/letras.asp?letra=801439
# Response from lyrics page: 200
# Title: Mágico México
# extracting song from: https://www.musica.com/letras.asp?letra=1585358
# Response from lyrics page: 200
# Title: Maldita bruja
# extracting song from: https://www.musica.com/letras.asp?letra=891992
# Response from lyrics page: 200
# Title: Manda una señal
# extracting song from: https://www.musica.com/letras.asp?letra=1094766
# Response from lyrics page: 200
# Title: Manda una señal en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=828763
# Response from lyrics page: 200
# Title: Mareo
# extracting song from: https://www.musica.com/letras.asp?letra=67292
# Response from lyrics page: 200
# Title: Mariposa Traicionera
# extracting song from: https://www.musica.com/letras.asp?letra=1032922
# Response from lyrics page: 200
# Title: Mariposa Traicionera en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2561973
# Response from lyrics page: 200
# Title: Mariposa Traicionera
# extracting song from: https://www.musica.com/letras.asp?letra=67944
# Response from lyrics page: 200
# Title: Me Vale
# extracting song from: https://www.musica.com/letras.asp?letra=964322
# Response from lyrics page: 200
# Title: Me Vale en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=828756
# Response from lyrics page: 200
# Title: Me voy a convertir en un ave
# extracting song from: https://www.musica.com/letras.asp?letra=801440
# Response from lyrics page: 200
# Title: Mentirosa
# extracting song from: https://www.musica.com/letras.asp?letra=828757
# Response from lyrics page: 200
# Title: México
# extracting song from: https://www.musica.com/letras.asp?letra=1962303
# Response from lyrics page: 200
# Title: Mi Corazon No Sabe Olvidar
# extracting song from: https://www.musica.com/letras.asp?letra=1957807
# Response from lyrics page: 200
# Title: Mi reina del dolor
# extracting song from: https://www.musica.com/letras.asp?letra=2209799
# Response from lyrics page: 200
# Title: Mi verdad
# extracting song from: https://www.musica.com/letras.asp?letra=806732
# Response from lyrics page: 200
# Title: Mis Ojos
# extracting song from: https://www.musica.com/letras.asp?letra=828758
# Response from lyrics page: 200
# Title: Mueve tus caderas
# extracting song from: https://www.musica.com/letras.asp?letra=825972
# Response from lyrics page: 200
# Title: Nada que perder
# extracting song from: https://www.musica.com/letras.asp?letra=1892914
# Response from lyrics page: 200
# Title: Nadie me va a parar
# extracting song from: https://www.musica.com/letras.asp?letra=801441
# Response from lyrics page: 200
# Title: Navidad
# extracting song from: https://www.musica.com/letras.asp?letra=1086746
# Response from lyrics page: 200
# Title: No estas sola
# extracting song from: https://www.musica.com/letras.asp?letra=133527
# Response from lyrics page: 200
# Title: No Ha Parado De Llover
# extracting song from: https://www.musica.com/letras.asp?letra=1148027
# Response from lyrics page: 200
# Title: No Ha Parado De Llover en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2489881
# Response from lyrics page: 200
# Title: No Ha Parado De Llover
# extracting song from: https://www.musica.com/letras.asp?letra=828765
# Response from lyrics page: 200
# Title: No me mires asi
# extracting song from: https://www.musica.com/letras.asp?letra=1957813
# Response from lyrics page: 200
# Title: No te rindas
# extracting song from: https://www.musica.com/letras.asp?letra=75335
# Response from lyrics page: 200
# Title: No Voy A Ser Tu Esclavo
# extracting song from: https://www.musica.com/letras.asp?letra=811691
# Response from lyrics page: 200
# Title: Nunca Más
# extracting song from: https://www.musica.com/letras.asp?letra=900679
# Response from lyrics page: 200
# Title: Ojalá pudiera borrarte
# extracting song from: https://www.musica.com/letras.asp?letra=1062303
# Response from lyrics page: 200
# Title: Ojalá pudiera borrarte en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1429195
# Response from lyrics page: 200
# Title: Ojala que te mueras
# extracting song from: https://www.musica.com/letras.asp?letra=79886
# Response from lyrics page: 200
# Title: Oye Mi Amor
# extracting song from: https://www.musica.com/letras.asp?letra=1094791
# Response from lyrics page: 200
# Title: Oye Mi Amor en español
# extracting song from: https://www.musica.com/letras.asp?letra=2216653
# Response from lyrics page: 200
# Title: Peligrosa
# extracting song from: https://www.musica.com/letras.asp?letra=133531
# Response from lyrics page: 200
# Title: Perdido En Un Barco
# extracting song from: https://www.musica.com/letras.asp?letra=1100007
# Response from lyrics page: 200
# Title: Pero me acuerdo de ti
# extracting song from: https://www.musica.com/letras.asp?letra=82590
# Response from lyrics page: 200
# Title: Pobre Juan
# extracting song from: https://www.musica.com/letras.asp?letra=1645891
# Response from lyrics page: 200
# Title: Poquito a poco
# extracting song from: https://www.musica.com/letras.asp?letra=801442
# Response from lyrics page: 200
# Title: Por que te vas
# extracting song from: https://www.musica.com/letras.asp?letra=2241764
# Response from lyrics page: 200
# Title: Porto do Amor
# extracting song from: https://www.musica.com/letras.asp?letra=960335
# Response from lyrics page: 200
# Title: Puerta azul
# extracting song from: https://www.musica.com/letras.asp?letra=828761
# Response from lyrics page: 200
# Title: Queremos paz
# extracting song from: https://www.musica.com/letras.asp?letra=85784
# Response from lyrics page: 200
# Title: Rayando El Sol
# extracting song from: https://www.musica.com/letras.asp?letra=964324
# Response from lyrics page: 200
# Title: Rayando El Sol en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2448134
# Response from lyrics page: 200
# Title: Rayando El Sol
# extracting song from: https://www.musica.com/letras.asp?letra=86535
# Response from lyrics page: 200
# Title: Refrigerador
# extracting song from: https://www.musica.com/letras.asp?letra=896026
# Response from lyrics page: 200
# Title: Relax
# extracting song from: https://www.musica.com/letras.asp?letra=887323
# Response from lyrics page: 200
# Title: Reloj Cucu
# extracting song from: https://www.musica.com/letras.asp?letra=1002192
# Response from lyrics page: 200
# Title: Rey Tiburon
# extracting song from: https://www.musica.com/letras.asp?letra=828762
# Response from lyrics page: 200
# Title: Robame el alma
# extracting song from: https://www.musica.com/letras.asp?letra=828741
# Response from lyrics page: 200
# Title: Robot
# extracting song from: https://www.musica.com/letras.asp?letra=801443
# Response from lyrics page: 200
# Title: Sabanas frías
# extracting song from: https://www.musica.com/letras.asp?letra=864196
# Response from lyrics page: 200
# Title: Sábanas frías (completa)
# extracting song from: https://www.musica.com/letras.asp?letra=91051
# Response from lyrics page: 200
# Title: Se Me Olvidó Otra Vez
# extracting song from: https://www.musica.com/letras.asp?letra=828764
# Response from lyrics page: 200
# Title: Selva negra
# extracting song from: https://www.musica.com/letras.asp?letra=892568
# Response from lyrics page: 200
# Title: Si ella me faltara alguna vez (a duo con Pablo Milanes)
# extracting song from: https://www.musica.com/letras.asp?letra=1249504
# Response from lyrics page: 200
# Title: Si fueras mi enemigo
# extracting song from: https://www.musica.com/letras.asp?letra=808745
# Response from lyrics page: 200
# Title: Si no estás Conmigo
# extracting song from: https://www.musica.com/letras.asp?letra=1263230
# Response from lyrics page: 200
# Title: Si no te hubieras ido
# extracting song from: https://www.musica.com/letras.asp?letra=1331070
# Response from lyrics page: 200
# Title: Si no te hubieras ido en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=1062400
# Response from lyrics page: 200
# Title: Si tu me quisieras
# extracting song from: https://www.musica.com/letras.asp?letra=828768
# Response from lyrics page: 200
# Title: Siembre el amor
# extracting song from: https://www.musica.com/letras.asp?letra=801444
# Response from lyrics page: 200
# Title: Sin tu cariño
# extracting song from: https://www.musica.com/letras.asp?letra=96244
# Response from lyrics page: 200
# Title: Soledad
# extracting song from: https://www.musica.com/letras.asp?letra=1776029
# Response from lyrics page: 200
# Title: Soledad en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=801445
# Response from lyrics page: 200
# Title: Sólo huele a tristeza
# extracting song from: https://www.musica.com/letras.asp?letra=1680888
# Response from lyrics page: 200
# Title: Solo Tu
# extracting song from: https://www.musica.com/letras.asp?letra=897090
# Response from lyrics page: 200
# Title: Somos Mar y Arena
# extracting song from: https://www.musica.com/letras.asp?letra=2216656
# Response from lyrics page: 200
# Title: Somos Más Americanos
# extracting song from: https://www.musica.com/letras.asp?letra=1956999
# Response from lyrics page: 200
# Title: Sor María
# extracting song from: https://www.musica.com/letras.asp?letra=2216140
# Response from lyrics page: 200
# Title: Suavecito
# extracting song from: https://www.musica.com/letras.asp?letra=800454
# Response from lyrics page: 200
# Title: Te llevare al cielo
# extracting song from: https://www.musica.com/letras.asp?letra=103464
# Response from lyrics page: 200
# Title: Te Lloré Todo Un Río
# extracting song from: https://www.musica.com/letras.asp?letra=1426968
# Response from lyrics page: 200
# Title: Te Llore Todo Un Rio (ingles)
# extracting song from: https://www.musica.com/letras.asp?letra=2568199
# Response from lyrics page: 200
# Title: Te Lloré Un Río
# extracting song from: https://www.musica.com/letras.asp?letra=103497
# Response from lyrics page: 200
# Title: Te Solte La Rienda
# extracting song from: https://www.musica.com/letras.asp?letra=894234
# Response from lyrics page: 200
# Title: Tengo muchas alas
# extracting song from: https://www.musica.com/letras.asp?letra=806492
# Response from lyrics page: 200
# Title: Tonto bajo la lluvia
# extracting song from: https://www.musica.com/letras.asp?letra=1006990
# Response from lyrics page: 200
# Title: Traicionera
# extracting song from: https://www.musica.com/letras.asp?letra=891977
# Response from lyrics page: 200
# Title: Tú me salvaste
# extracting song from: https://www.musica.com/letras.asp?letra=828770
# Response from lyrics page: 200
# Title: Tu tienes lo que quiero
# extracting song from: https://www.musica.com/letras.asp?letra=828769
# Response from lyrics page: 200
# Title: Un lobo por tu amor
# extracting song from: https://www.musica.com/letras.asp?letra=2093909
# Response from lyrics page: 200
# Title: Un Nuevo Amanecer
# extracting song from: https://www.musica.com/letras.asp?letra=1766519
# Response from lyrics page: 200
# Title: Vete con el amor
# extracting song from: https://www.musica.com/letras.asp?letra=865334
# Response from lyrics page: 200
# Title: Vivir sin aire
# extracting song from: https://www.musica.com/letras.asp?letra=818275
# Response from lyrics page: 200
# Title: Vivir sin aire en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2627599
# Response from lyrics page: 200
# Title: Vivir Sin Aire
# extracting song from: https://www.musica.com/letras.asp?letra=2141430
# Response from lyrics page: 200
# Title: Você É Minha Religião
# extracting song from: https://www.musica.com/letras.asp?letra=1957815
# Response from lyrics page: 200
# Title: Vuela libre paloma
# extracting song from: https://www.musica.com/letras.asp?letra=1110494
# Response from lyrics page: 200
# Title: Ya me voy
# extracting song from: https://www.musica.com/letras.asp?letra=961837
# Response from lyrics page: 200
# Title: Ya no me mires asi
# extracting song from: https://www.musica.com/letras.asp?letra=1216499
# Response from lyrics page: 200
# Title: Zaragoza Sigue Aqui
# 'Mana\n===\nTítulo: Adicto A Tu Amor \n\n Adicto A Tu Amor\nCon ella\nEstoy adicto a su sexy amor\nPara mi en su velar, me hace alucinar\nSoy un convicto de tu amor\nY es que te beso en la cocina\nTe hago el amor en la oficina\nNo logro evitar, voy a penetrar\nEse arcoiris me fascina\nSuben, mis labios quieren subir hasta tus caderas\nMis labios quieren bajar, hasta tu pecera\nMami soy un adicto de tu amor, no lo puedo negar\nEres mi pasión, eres mi obsesión\nEres tu mi adicción, eres tu mi sol\nSoy adicto de tu amor, no lo puedo negar\nSoy adicto de tu amor\nEres mi pasión, eres mi obsesión\nEres tu mi adicción, eres tu mi sol\nAddict, no lo puedo negar\nAddict...\nQue manera hermosa como muerdes\nHay algo de sexy en tu mirar\nSoy como un volcán y tu falda cae\nEstamos empapados en amor\nSuben, mis labios quieren subir hasta tus caderas\nMis labios quieren bajar, hasta tu pecera\nMami soy un adicto de tu amor, no lo puedo negar\nEres mi pasión, eres mi obsesión\nEres tu mi adicción, eres tu mi sol\nSoy adicto de tu amor, no lo puedo negar\nSoy adicto de tu amor\nEres mi pasión, eres mi obsesión\nEres tu mi adicción, eres tu mi sol\nAddict, no lo puedo negar\nTe amaría noche y día\nTe amaría de por vida\nEs una adicción\nNo lo puedo negar!\nNo lo puedo negar\nEres mi pasión, eres mi obsesión\nEres tu mi adicción, eres tu mi sol\nNo lo puedo negar, no lo puedo negar\nAdicción, obsesión, adicción\nPierdo, pierdo la razón\nSe que soy adicto\nAdicto de tu amor\nNo lo puedo negar\n\n===\n\nTítulo: Ahi esta la luna \n\n Ahi esta la luna\nDime luna\npor que me miras siempre asi\nhey dime luna.\nEs que yo no ,no te puedo ocultar,oh,no,no,no\nluna me haces recordar.\nte he perdido y me he desecho de todos\ntus recuerdos\ncartas, discos ,fotos,mi amor,\ntodo ya lo tire o lo oculte,pero la luna sigue ahi\nYa cambie de mundo para olvidarla\nme fui hasta madrid,el cairo y new york,\nya he quitado todos sus recuerdos pero yo\nno la puedo olvidar\nCORO\nAhi esta la luna,\ncomo se podria quitar del cielo la luna,\ncomo se podria arrancar pa siempre del cielo\ny asi librarme yo de este anhelo\nhey, dime luna por que me miras no sera\nque estas enamorada que no te puedo\nocultar oh no no no\nluna me haces recordar\nTe he perdido ya regale tu perro tu guitarra y tus anillos\nya evite tus calles tus antros tus amigos\npero yo no puedo no no no quitar la luna\nYa me he sumergido en una caracola\nme fui hasta el tibet y al fondo del mar\nya he quitado todos tus recuerdos\nno le puedo olvidar\nCORO\nAhi esta la luna\ncomo se podria quitar del cielo la luna\ncomo le hare pa rodarla quitarla del cielo\ny asi librarme yo de este anhelo\n\n===\n\nTítulo: Ámame Hasta Que Me Muera \n\n Ámame Hasta Que Me Muera\nVen y empapame de amor\nven y apagame este ardor\nyo quiero ahogarme en ti\nen tus muslos naufragar\namame hasta que mi piel\nse huela a amaneceres\ny no sepamos nunca mas donde esta\nel cielo o el suelo\nDame amor 10 veces\ndame amor, hazme el amor\ndame amor 100 veces\ndame amor hasta que yo me muera\nQuiero derretrime en ti\npenetrar hasta tu corazon\nyo quiero sembrarme en ti\nsembrarme pa\' siempre\namemonos hasta embriagar, embriagar\nel alma\ny no sepamos nunca mas donde esta\nel cielo o el suelo\nDame amor 10 veces\ndame amor, hazme el amor\ndame amor 100 veces\ndame amor hasta que yo me muera\ndame amor 10 veces\ndame amor, hazme el amor\ndame amor 100 veces\ndame amor hasta que yo me muera\nNiña de mi amor pierdete en mis mares\nniña de mi amor nada en mis rincones\nno te puedes ir niña de mis sueños\nno me dejes mas quiero ser tu dueño\nDame amor 10 veces\ndame amor, hazme el amor\ndame amor 100 veces\ndame amor hasta que yo me muera\nDame amor 10 veces\ndame amor, hazme el amor\ndame amor 100 veces\ndame amor hasta que yo me muera\n\n\n===\n\n\n\n===\n\nTítulo: Amor Clandestino \n\n Amor Clandestino\nEres inevitable amor\nCasi como respirar\nCasi como respirar\nLlega tus playas impuntual pero no me rendiré\nSoy tu amor clandestino\nSoy  ...

# %%
from dotenv import load_dotenv
import openai
import os
from llama_index.core import (
    VectorStoreIndex, 
    SimpleDirectoryReader, 
    StorageContext,
    load_index_from_storage,
    Document,
    PromptTemplate
)
load_dotenv()
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI

# override default LLM 
llm = OpenAI(model="gpt-4o-mini")
Settings.llm = llm

# %%
def get_artist_documents(filename: str) -> list[Document]:
    with open(filename) as file:
        data = file.read()
    songs = data.split("===")
    artist = songs.pop(0).strip()
    
    documents = [
        Document(
            text=song,
            metadata={
                "category":"music",
                "artist": artist,
            }
        )
        for song in songs
    ]    
    return documents

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

embed_model = HuggingFaceEmbedding(model_name="intfloat/multilingual-e5-base")
Settings.embed_model = embed_model

# %%
PERSIST_DIR = "lyrics_index"

if not os.path.exists(PERSIST_DIR):
    documents = get_artist_documents("8988_Kjarkas.txt")
    index = VectorStoreIndex.from_documents(documents, show_progress=True)
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR) 
    index = load_index_from_storage(storage_context)

# %%
query_engine = index.as_query_engine(verbose=True)

# %%
qa_template_str = """
    You are an expert in Bolivian Folk music, your task is to guide and teach the user 
    about your field. Answer the user queries only with supported data in your context.
    Your context may contain complete lyrics or parts of them in different languages, but
    your answer will always be in Spanish. 

    Context information is below.
    ---------------------
    {context_str}
    ---------------------
    Given the context information and not prior knowledge, 
    answer the query with detailed source information, include direct quotes and use bullet lists in your 
    answers, in one of the bullets detail the tone/sentiment of the song.
    Query: {query_str}
    Answer: 
"""
qa_template = PromptTemplate(qa_template_str)

# %%
query_engine.update_prompts(
    {"response_synthesizer:text_qa_template": qa_template}
)

# %%
response = query_engine.query("cuales canciones de los Kjarkas hablan de abandono?")

# %%
from IPython.display import Markdown, display
display(Markdown(response.response))
# Out:
# Las canciones de los Kjarkas que hablan de abandono son:
#
# - **"Llorando se fue"**
#   - Esta canción trata sobre el dolor de una separación y el recuerdo de un amor perdido.
#   - Frases clave:
#     - "Llorando se fue y me dejo solo y sin su amor"
#     - "Sola estará recordando este amor que el tiempo no puede borrar"
#   - **Sentimiento**: La canción transmite un tono de tristeza y melancolía por la pérdida de un amor.
#
# - **"El adios"**
#   - En esta canción se aborda el tema de la despedida y el reconocimiento de que el amor no siempre es correspondido.
#   - Frases clave:
#     - "adios mi amor buena suerte hasta que el tiempo nos junte"
#     - "perdoname si al final solo te causado mal"
#   - **Sentimiento**: La canción tiene un tono de resignación y aceptación, reflejando el dolor de la separación pero también un deseo de bienestar para la otra persona.
#
# Ambas canciones reflejan el tema del abandono y el dolor que este provoca en las relaciones amorosas.

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='19962fee-3e2c-4030-9c52-e18a03c6bf06', embedding=None, metadata={'category': 'music', 'artist': 'Kjarkas'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='3a1b3116-648a-4810-94c9-dac1e1d3d045', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'category': 'music', 'artist': 'Kjarkas'}, hash='73db528cf327371bab0c26d5a454eedb385dc9c18e751056e7e115a1632b1f94')}, text='Título: Llorando se fue \n\n Llorando se fue\nLlorando se fue\ny me dejo solo y sin su amor\nLlorando se fue\ny me dejo solo y con dolor\nSola estará recordando este amor\nque el tiempo no puede borrar\nSola estará recordando este amor\nque el tiempo no puede borrar\nLa recuerdo hoy\ny en mi pecho no existe el rencor\nLa recuerdo hoy\ny en mi pecho solo existe amor\nLlorando estará recordando este amor\nque un dia no supo cuidar\nLlorando estará recordando este amor\nque un dia no supo cuidar\n(Bis)', start_char_idx=2, end_char_idx=487, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=np.float64(0.8499779155182586)),
#  NodeWithScore(node=TextNode(id_='39da7028-54f2-406f-a61e-ba9b63880e93', embedding=None, metadata={'category': 'music', 'artist': 'Kjarkas'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='bc81430b-cb77-452d-b930-5e29a7a62021', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'category': 'music', 'artist': 'Kjarkas'}, hash='2c408473c1adbd3ae4e23e552a800a701ee0a247603adb122005cc272140ab72')}, text='Título: El adios \n\n El adios\nadios mi amor buena suerte\nhasta que el tiempo nos junte\nadios sigo mi camino\nrecuerdame con cariño\nadios sigo mi camino\nrecuerdame con cariño\nperdoname si al final\nsolo te causado mal\nyono te exijo quererme\nsolo vien a despedirme\nyono te exijo quererme\nsolo vien a despedirme\nsi te niegas quererme\nyo te doy toda razon\nde no aceptar ciegamente\nlo que dicata el corazon\nde no aceptar ciegamente\nlo que dicata el corazon\nsi se perdio sin remedio\nen el afan de quererte\nlo que la vida me dio\no en el tener mala suerte\nlo que la vida me dio\no en el tener mala suerte\nguitarra\nperdoname si al final\nsolo te causado mal\nyono te exijo quererme\nsolo vien a despedirme\nyono te exijo quererme\nsolo vien a despedirme\nsi te niegas quererme\nyo te doy toda razon\nde no aceptar ciegamente\nlo que dicata el corazon\nde no aceptar ciegamente\nlo que dicata el corazon\nsi se perdio sin remedio\nen el afan de quererte\nlo que la vida me dio\no en el tener mala suerte\nlo que la vida me dio\no en el tener mala suerte\nzampoña', start_char_idx=2, end_char_idx=1032, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=np.float64(0.8497017246053514))]

# %%
chat_engine = index.as_chat_engine(verbose=True)

# %%
response = chat_engine.chat("que canciones de los kjarkas hablan de abandono?")
# Out:
# Added user message to memory: que canciones de los kjarkas hablan de abandono?
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"canciones de los Kjarkas que hablan de abandono"}
# Got output: Las canciones de Kjarkas que hablan de abandono son "Al partir" y "El adios". Ambas canciones expresan sentimientos de tristeza y despedida, reflejando el dolor de dejar a un ser querido.
# ========================

# %%
display(Markdown(response.response))
# Out:
# Las canciones de Los Kjarkas que hablan de abandono son "Al partir" y "El adiós". Ambas expresan sentimientos de tristeza y despedida, reflejando el dolor de dejar a un ser querido.

# %%
display(Markdown(chat_engine.chat("y cuales hablan de la naturaleza?").response))
# Out:
# Added user message to memory: y cuales hablan de la naturaleza?
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"canciones de los Kjarkas que hablan de la naturaleza"}
# Got output: Las canciones de Kjarkas que mencionan elementos de la naturaleza incluyen "Canto a la madre" y "Canto a la mujer de mi pueblo." Ambas canciones hacen referencia a montañas, pueblos perdidos, y la conexión con la tierra, destacando la belleza y la esperanza que se encuentran en el entorno natural.
# ========================
# Las canciones de Los Kjarkas que hablan de la naturaleza incluyen "Canto a la madre" y "Canto a la mujer de mi pueblo." Ambas hacen referencia a montañas, pueblos perdidos y la conexión con la tierra, destacando la belleza y la esperanza que se encuentran en el entorno natural.
